# %% [markdown]
# Theories to pursue:

# %% [markdown]
# https://ciphermysteries.com/2009/06/06/the-voynich-cipher-for-code-breakers
#
# 1) number encoding
# The repetitions superficially appear page numbers (eg. aiiir)...
# but are in fact encoded with dots (steganography)
#
# ..and so the "page references" actually are a way to encode NUMERALS
#
# 2) apparent "CVCVCV" structure
